# %%
import requests
import json
import time
from dataclasses import dataclass
from pyspark.sql import SparkSession

# %%
#Test PySpark to Dataframe
colums = ["id", "name", "latitude", "longitude", "bikes", "free", "timestamp"]
data = [[1, "Test", 1.0, 1.0, 1, 1, 1]]
spark = SparkSession.builder.appName("Python Spark SQL basic example").getOrCreate()
rdd = spark.sparkContext.parallelize(data)

df = spark.createDataFrame(rdd, colums)
df.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [24], line 4
#       2 colums = ["id", "name", "latitude", "longitude", "bikes", "free", "timestamp"]
#       3 data = [[1, "Test", 1.0, 1.0, 1, 1, 1]]
# ----> 4 spark = SparkSession.builder.appName("Python Spark SQL basic example").getOrCreate()
#       5 rdd = spark.sparkContext.parallelize(data)
#       7 df = spark.createDataFrame(rdd, colums)
#
# File c:\Users\nikib\.virtualenvs\DADP-IQarI-ig\lib\site-packages\pyspark\sql\session.py:269, in SparkSession.Builder.getOrCreate(self)
#     267     sparkConf.set(key, value)
#     268 # This SparkContext may be an existing one.
# --> 269 sc = SparkContext.getOrCreate(sparkConf)
#     270 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     271 # by all sessions.
#     272 session = SparkSession(sc, options=self._options)
#
# File c:\Users\nikib\.virtualenvs\DADP-IQarI-ig\lib\site-packages\pyspark\context.py:483, in SparkContext.getOrCreate(cls, conf)
#     481 with SparkContext._lock:
#     482     if SparkContext._active_spark_context is None:
# --> 483         SparkContext(conf=conf or SparkConf())
#     484     assert SparkContext._active_spark_context is not None
#     485     return SparkContext._active_spark_context
#
# File c:\Users\nikib\.virtualenvs\DADP-IQarI-ig\lib\site-packages\pyspark\context.py:195, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls)
#     189 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     190     raise ValueError(
#     191         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     192         " is not allowed as it is a security risk."
#     193     )
# --> 195 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     196 try:
#     197     self._do_init(
#     198         master,
#     199         appName,
#    (...)
#     208         udf_profiler_cls,
#     209     )
#
# File c:\Users\nikib\.virtualenvs\DADP-IQarI-ig\lib\site-packages\pyspark\context.py:417, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     415 with SparkContext._lock:
#     416     if not SparkContext._gateway:
# --> 417         SparkContext._gateway = gateway or launch_gateway(conf)
#     418         SparkContext._jvm = SparkContext._gateway.jvm
#     420     if instance:
#
# File c:\Users\nikib\.virtualenvs\DADP-IQarI-ig\lib\site-packages\pyspark\java_gateway.py:106, in launch_gateway(conf, popen_kwargs)
#     103     time.sleep(0.1)
#     105 if not os.path.isfile(conn_info_file):
# --> 106     raise RuntimeError("Java gateway process exited before sending its port number")
#     108 with open(conn_info_file, "rb") as info:
#     109     gateway_port = read_int(info)
#
# RuntimeError: Java gateway process exited before sending its port number

# %% [markdown]
# ### Get all Data with one request

# %%
import time


# while True:
resp = requests.get("https://iot.hamburg.de/v1.1/Things?$filter=Datastreams/properties/serviceName%20eq%20%27HH_STA_AutomatisierteVerkehrsmengenerfassung%27&$count=true&$expand=Locations,Datastreams($expand=Observations($top=3;$orderby=phenomenonTime%20desc),Sensor,ObservedProperty)")

response = json.loads(resp.content)
if resp.status_code == 200:
    print("OK")
    for feature in response['value']:
        print(feature['@iot.id'])
        for stream in feature['Datastreams']:
            if "Kfz" not in stream['description']:
                _ = print(stream['description'])
                _ = print(stream['Observations'][0]['result'])

        print("---------------------")
        
        # break
else:
    print("NOT OK")

    # time.sleep(300)
# print(ids, len(ids))
# Out:
# OK
# 5564
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Woche-Intervall aufsummiert.
# 38875
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 42
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 167
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Tag-Intervall aufsummiert.
# 4968
# ---------------------
# 5565
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 27
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 107
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Woche-Intervall aufsummiert.
# 21005
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Tag-Intervall aufsummiert.
# 2827
# ---------------------
# 5566
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 15
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 60
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Woche-Intervall aufsummiert.
# 17870
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Tag-Intervall aufsummiert.
# 2141
# ---------------------
# 5583
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 15
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Woche-Intervall aufsummiert.
# 7836
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Tag-Intervall aufsummiert.
# 1076
# ---------------------
# 5600
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 8
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Woche-Intervall aufsummiert.
# 2634
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Tag-Intervall aufsummiert.
# 347
# ---------------------
# 5636
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 36
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Woche-Intervall aufsummiert.
# 11634
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Tag-Intervall aufsummiert.
# 1587
# ---------------------
# 5639
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 16
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Woche-Intervall aufsummiert.
# 4796
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Tag-Intervall aufsummiert.
# 693
# ---------------------
# 5642
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 35
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Tag-Intervall aufsummiert.
# 738
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Woche-Intervall aufsummiert.
# 6390
# ---------------------
# 5808
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 40
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Woche-Intervall aufsummiert.
# 14892
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 7
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Tag-Intervall aufsummiert.
# 1943
# ---------------------
# 5816
# ---------------------
# 5862
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 79
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 20
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Woche-Intervall aufsummiert.
# 30434
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Tag-Intervall aufsummiert.
# 3919
# ---------------------
# 5863
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 13
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 39
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Woche-Intervall aufsummiert.
# 15542
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Tag-Intervall aufsummiert.
# 1976
# ---------------------
# 5905
# ---------------------
# 5906
# ---------------------
# 5907
# ---------------------
# 5908
# ---------------------
# 5909
# ---------------------
# 5910
# ---------------------
# 5911
# ---------------------
# 5912
# ---------------------
# 5913
# ---------------------
# 5914
# ---------------------
# 5915
# ---------------------
# 5916
# ---------------------
# 5917
# ---------------------
# 5918
# ---------------------
# 5919
# ---------------------
# 5920
# ---------------------
# 5921
# ---------------------
# 5922
# ---------------------
# 5923
# ---------------------
# 5924
# ---------------------
# 5925
# ---------------------
# 5926
# ---------------------
# 5927
# ---------------------
# 5928
# ---------------------
# 5929
# ---------------------
# 5930
# ---------------------
# 5931
# ---------------------
# 5932
# ---------------------
# 5933
# ---------------------
# 5934
# ---------------------
# 5935
# ---------------------
# 5936
# ---------------------
# 5937
# ---------------------
# 5938
# ---------------------
# 5939
# ---------------------
# 5940
# ---------------------
# 5941
# ---------------------
# 5942
# ---------------------
# 5943
# ---------------------
# 5944
# ---------------------
# 5945
# ---------------------
# 5946
# ---------------------
# 5947
# ---------------------
# 5948
# ---------------------
# 5949
# ---------------------
# 5950
# ---------------------
# 5951
# ---------------------
# 5952
# ---------------------
# 5953
# ---------------------
# 5954
# ---------------------
# 5955
# ---------------------
# 5956
# ---------------------
# 5957
# ---------------------
# 5958
# ---------------------
# 5959
# ---------------------
# 5960
# ---------------------
# 5961
# ---------------------
# 5962
# ---------------------
# 5963
# ---------------------
# 5964
# ---------------------
# 5965
# ---------------------
# 5966
# ---------------------
# 5967
# ---------------------
# 5968
# ---------------------
# 5969
# ---------------------
# 5970
# ---------------------
# 5971
# ---------------------
# 5972
# ---------------------
# 5973
# ---------------------
# 5974
# ---------------------
# 5975
# ---------------------
# 5976
# ---------------------
# 5977
# ---------------------
# 5978
# ---------------------
# 5979
# ---------------------
# 5980
# ---------------------
# 5981
# ---------------------
# 5982
# ---------------------
# 5983
# ---------------------
# 5984
# ---------------------
# 5985
# ---------------------
# 5986
# ---------------------
# 5987
# ---------------------
# 5988
# ---------------------
# 5989
# ---------------------
# 5990
# ---------------------
# 5991
# ---------------------
# 5992
# ---------------------

# %% [markdown]
# ### Just 15 Min Data

# %%
@dataclass
class BikeSensor15Min:
    id: int
    name: str
    count: int
    time: str
    coordinateType: str
    coordinates: list

# class BikeSensor15Min:

# while True:
resp = requests.get("https://iot.hamburg.de/v1.0/Things?$filter=Datastreams/properties/serviceName%20eq%20%27HH_STA_HamburgerRadzaehlnetz%27%20and%20Datastreams/properties/layerName%20eq%20%27Anzahl_Fahrraeder_Zaehlfeld_15-Min%27&$count=true&$expand=Datastreams($filter=properties/layerName%20eq%20%27Anzahl_Fahrraeder_Zaehlfeld_15-Min%27;$expand=Observations($top=1;$orderby=phenomenonTime%20desc))")
response = json.loads(resp.content)
done = False
cnt = 0
sensors = []
while(not done):
    if resp.status_code == 200:
        for feature in response['value']:
            for stream in feature['Datastreams']:
                if len(stream['Observations']) > 0:
                    print(stream['description'])
                    print(stream['Observations'][0]['result'])
                    print(stream['Observations'][0]['phenomenonTime'])
                    bikesensor = BikeSensor15Min(feature['@iot.id'], feature['name'], stream['Observations'][0]['result'], stream['Observations'][0]['phenomenonTime'], stream['observedArea']['type'], stream['observedArea']['coordinates'])
                    sensors.append(bikesensor)
                else:
                    print(stream['description'])
                    print(0)
                    bikesensor = BikeSensor15Min(feature['@iot.id'], feature['name'], 0, stream['Observations'][0]['phenomenonTime'], stream['observedArea']['type'], stream['observedArea']['coordinates'])
                    sensors.append(bikesensor)
            print("---------------------")

            cnt += 1
    else:
        print("NOT OK")
    if '@iot.nextLink' not in response:
        done = True
    else:
        resp = requests.get(response['@iot.nextLink'])
        response = json.loads(resp.content)



print(cnt)
    # time.sleep(300)
# print(ids, len(ids))
# Out:
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 9
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 9
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 12
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 6
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 10
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 7
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 12
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 9
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 13
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 22
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 30
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 5
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 16
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 11
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 9
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 12
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 10
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 10
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 9
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 11
# 2022-12-10T09:45:00.000Z/2022-12-10T09:59:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T09:45:00.000Z/2022-12-10T09:59:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T09:45:00.000Z/2022-12-10T09:59:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 22
# 2022-12-10T09:45:00.000Z/2022-12-10T09:59:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 12
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 7
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 6
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 13
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 14
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 8
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 6
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 11
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 6
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 6
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 16
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 17
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 25
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 8
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 16
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T03:45:00.000Z/2022-12-10T03:59:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T03:45:00.000Z/2022-12-10T03:59:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 32
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 32
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 6
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 7
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 5
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 5
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 16
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 21
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 7
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 9
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 1
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 15
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 7
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 10
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 7
# 2022-12-10T10:45:00.000Z/2022-12-10T10:59:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 11
# 2022-12-10T10:45:00.000Z/2022-12-10T10:59:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 5
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 2
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 5
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 10
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 5
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 4
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 3
# 2022-12-10T11:00:00.000Z/2022-12-10T11:14:59.000Z
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# Die Anzahl der von der Infrarotdetektor erfassten Fahrräder wird für ein 15-Min-Intervall aufsummiert.
# 0
# ---------------------
# 195

# %% [markdown]
# ### Just 1 Hour Data

# %%
import time


# while True:
resp = requests.get("https://iot.hamburg.de/v1.0/Things?$filter=Datastreams/properties/serviceName%20eq%20%27HH_STA_HamburgerRadzaehlnetz%27%20and%20Datastreams/properties/layerName%20eq%20%27Anzahl_Fahrraeder_Zaehlstelle_1-Stunde%27&$count=true&$expand=Datastreams($filter=properties/layerName%20eq%20%27Anzahl_Fahrraeder_Zaehlstelle_1-Stunde%27;$expand=Observations($top=1;$orderby=phenomenonTime%20desc))")
response = json.loads(resp.content)
if resp.status_code == 200:
    print("OK")
    for feature in response['value']:
        print(feature['@iot.id'])
        for stream in feature['Datastreams']:
            if len(stream['Observations']) > 0:
                print(stream['description'])
                print(stream['Observations'][0]['result'])
        
        # break
else:
    print("NOT OK")

    # time.sleep(300)
# print(ids, len(ids))
# Out:
# OK
# 5564
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 193
# 5565
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 61
# 5566
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 132
# 5570
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 74
# 5571
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 26
# 5572
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 48
# 5573
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 29
# 5574
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 3
# 5575
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 5
# 5576
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 2
# 5577
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 3
# 5579
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 8
# 5583
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 33
# 5584
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 18
# 5585
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 8
# 5586
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 10
# 5589
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 4
# 5590
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 46
# 5591
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 12
# 5592
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 34
# 5593
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 137
# 5594
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 51
# 5595
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 86
# 5596
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 3
# 5597
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 1
# 5598
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 2
# 5600
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 12
# 5604
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 7
# 5606
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 77
# 5609
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 2
# 5613
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 12
# 5616
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 12
# 5617
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 25
# 5618
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 18
# 5619
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 7
# 5620
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 18
# 5621
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 8
# 5622
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 10
# 5623
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 96
# 5624
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 58
# 5625
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 38
# 5626
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 42
# 5627
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 21
# 5628
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 21
# 5629
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 25
# 5630
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 8
# 5631
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 17
# 5633
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 53
# 5636
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 78
# 5639
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 24
# 5642
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 25
# 5644
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 83
# 5645
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 49
# 5646
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 34
# 5647
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 6
# 5648
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 4
# 5649
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 2
# 5650
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 26
# 5801
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 27
# 5802
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 19
# 5803
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 0
# 5804
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 34
# 5805
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 25
# 5806
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 9
# 5807
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 3
# 5808
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 53
# 5809
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 94
# 5810
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 20
# 5811
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 74
# 5812
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 33
# 5813
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 24
# 5814
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 9
# 5815
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 24
# 5817
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 5
# 5818
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 101
# 5819
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 72
# 5820
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 29
# 5854
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 17
# 5855
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 14
# 5856
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 72
# 5857
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 0
# 5858
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 72
# 5859
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 18
# 5860
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 6
# 5861
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 12
# 5862
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 128
# 5863
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 75
# 5864
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 14
# 5865
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 23
# 5866
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 15
# 5867
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 4
# 5868
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 11
# 5869
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 44
# 5870
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 20
# 5871
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 8
# 5872
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 3
# 5873
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 2
# 5880
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 20
# 5881
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 23
# 5882
# Die Anzahl der vom Infrarotdetektor erfassten Fahrräder wird für ein 1-Stunde-Intervall aufsummiert.
# 16
